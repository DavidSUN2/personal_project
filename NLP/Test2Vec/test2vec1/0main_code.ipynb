# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
cd '/content/gdrive/My Drive/Colab/code2vec0'
# Out:
# /content/gdrive/My Drive/Colab/code2vec0

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import tensorflow as tf; print(tf.__version__)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0

# %%
# !source preprocess.sh
# Out:
# Extracting paths from validation set...
# Finished extracting paths from validation set
# Extracting paths from test set...
# Finished extracting paths from test set
# Extracting paths from training set...
# Finished extracting paths from training set
# Creating histograms from the training data
# File: my_dataset.test.raw.txt
# Average total contexts: 490.1029207232267
# Average final (after sampling) contexts: 165.26008344923505
# Total examples: 719
# Empty examples: 0
# Max number of contexts per word: 5007
# File: my_dataset.val.raw.txt
# Average total contexts: 537.4744186046512
# Average final (after sampling) contexts: 151.12403100775194
# Total examples: 645
# Empty examples: 0
# Max number of contexts per word: 15692
# File: my_dataset.train.raw.txt
# Average total contexts: 277.25880803424434
# Average final (after sampling) contexts: 109.9913840412688
# Total examples: 36444
# Empty examples: 0
# Max number of contexts per word: 45035
# ...

# %%
# !source train_tf.sh
# Out:
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab/code2vec0/model.py:16: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-12-17 07:08:24.804299: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-12-17 07:08:24.883073: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-17 07:08:24.883946: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-12-17 07:08:24.910051: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python3 code2vec.py --load models/test2vec/saved_model --release --test blabla
# Out:
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab/code2vec0/model.py:16: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-12-17 07:11:42.993695: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-12-17 07:11:43.016004: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-17 07:11:43.016906: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-12-17 07:11:43.024390: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python3 code2vec.py --load models/test2vec/saved_model --test data/my_dataset/my_dataset.test.c2v
# Out:
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab/code2vec0/model.py:16: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-12-17 07:13:09.494508: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-12-17 07:13:09.513880: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-17 07:13:09.514584: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-12-17 07:13:09.514848: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python3 code2vec.py --load models/test2vec/saved_model --save_w2v models/test2vec/tokens.txt
# Out:
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab/code2vec0/model.py:16: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-12-17 07:14:20.601780: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-12-17 07:14:20.623790: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-17 07:14:20.624530: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-12-17 07:14:20.624824: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python3 code2vec.py --load models/test2vec/saved_model --save_t2v models/test2vec/targets.txt
# Out:
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab/code2vec0/model.py:16: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-12-17 07:14:35.409418: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-12-17 07:14:35.428926: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-17 07:14:35.429838: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-12-17 07:14:35.430136: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python3 code2vec.py --load models/test2vec/saved_model --test data/my_dataset/my_dataset.test.c2v --export_code_vectors
# Out:
# WARNING:tensorflow:From /content/gdrive/My Drive/Colab/code2vec0/model.py:16: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-12-17 07:14:54.978778: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-12-17 07:14:54.997367: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-17 07:14:54.998238: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-12-17 07:14:54.998535: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
from gensim.models import KeyedVectors as word2vec
vectors_text_path = 'models/targets.txt'
model = word2vec.load_word2vec_format(vectors_text_path, binary=False)
model.most_similar(positive=['test|int'])
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('test|long|array', 0.8779067993164062),
#  ('test|double', 0.8600559830665588),
#  ('test|float|array', 0.8592281937599182),
#  ('test|long', 0.8500288128852844),
#  ('test|short|array', 0.8471531867980957),
#  ('test|char|array', 0.8454396724700928),
#  ('test|operate', 0.845423698425293),
#  ('test|byte|array', 0.8446964621543884),
# ...

# %%
model.most_similar(positive=['test|constructor'])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('test|constructor|rp|ri', 0.8488256335258484),
#  ('test|copy', 0.8374332189559937),
#  ('test|blank', 0.8372101187705994),
#  ('test|constants', 0.8311334848403931),
#  ('test|add|or|update', 0.8231515884399414),
#  ('test|constructor|rd|ri', 0.8229354619979858),
#  ('test|compare|to', 0.8229306936264038),
#  ('test|long', 0.820491373538971),
#  ('test|equals|object|list', 0.8161085844039917),
#  ('test|increment', 0.8150892853736877)]

# %%
model.most_similar(positive=['test|int', 'test|long'], negative=['test|float'])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('test|long|array', 0.7847533822059631),
#  ('test|append|super', 0.7685711979866028),
#  ('test|operate', 0.75435870885849),
#  ('test|object|array', 0.742287278175354),
#  ('test|scalar|add', 0.7413718700408936),
#  ('test|char', 0.7400477528572083),
#  ('test|premultiply|vector', 0.7389782667160034),
#  ('test|serial', 0.7337502241134644),
#  ('test|negate', 0.7297370433807373),
#  ('test|plus|minus', 0.7259860634803772)]
